# %% [markdown]
# # Coursera Capstone
#
# ### Introduction and Business Problem
#
# Question:  Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.
#
# Answer:
#
# Two historic and very popular jazz clubs have recently closed in the District of Columbia.  This leaves a underserved market.  In this assignment I seek to determine what neighborhood is the best to open a new jazz club.
#
# ### The Data
#
# Question 2:  Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data.
#
# Answer:  The Foursquare API provides the category of "jazz clubs."  The idea is to cluster the neighborhoods and determine where the hotbeds of jazz are.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Provide criteria for the Foursquare API

CLIENT_ID = 'OCWMDYHM2G1414ACMQSU1M4JUE2RGENSCHFRUDUYSIAKH4EC' # your Foursquare ID
CLIENT_SECRET = 'T3ZHW0FVTOXETI3WBQN1WJVWZ4IS1K02KKCUOPVEW5EJTQ0Z' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: OCWMDYHM2G1414ACMQSU1M4JUE2RGENSCHFRUDUYSIAKH4EC
# CLIENT_SECRET:T3ZHW0FVTOXETI3WBQN1WJVWZ4IS1K02KKCUOPVEW5EJTQ0Z

# %%
# Locate address in Washington, DC to get a lat long - use White House

address = '1600 Pennsylvania Ave NW, Washington, DC'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 38.8976998 -77.03655348862276

# %%
# Search for a specific category

search_query = 'jazz club'
radius = 500
print(search_query + ' .... OK!')
# Out:
# jazz club .... OK!

# %%
# Add search query to url 

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=OCWMDYHM2G1414ACMQSU1M4JUE2RGENSCHFRUDUYSIAKH4EC&client_secret=T3ZHW0FVTOXETI3WBQN1WJVWZ4IS1K02KKCUOPVEW5EJTQ0Z&ll=38.8976998,-77.03655348862276&v=20180604&query=jazz club&radius=500&limit=30'

# %%
# get the json from Foursquare

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e3505029fcb92001bf5896a'},
#  'response': {'venues': [{'id': '4b5dce76f964a520b96c29e3',
#     'name': 'Club Quarters Hotel in Washington DC',
#     'location': {'address': '839 17th Street NW',
#      'lat': 38.901081,
#      'lng': -77.039172,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.901081,
#        'lng': -77.039172}],
#      'distance': 439,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['839 17th Street NW',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4a8c8166f964a520470e20e3',
#     'name': 'The Bombay Club',
#     'location': {'address': '815 Connecticut Ave NW',
#      'lat': 38.90082247535677,
#      'lng': -77.03824645696865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90082247535677,
#        'lng': -77.03824645696865}],
#      'distance': 377,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['815 Connecticut Ave NW',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4ab16c5df964a5206b6920e3',
#     'name': 'The National Press Club',
#     'location': {'address': '529 14th St NW',
#      'crossStreet': 'F St. NW',
#      'lat': 38.897100844208715,
#      'lng': -77.0313054452996,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.897100844208715,
#        'lng': -77.0313054452996}],
#      'distance': 459,
#      'postalCode': '20045',
#      'cc': 'US',
#      'neighborhood': 'Downtown-Penn Quarter-Chinatown',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW (F St. NW)',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '66869294'},
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '46a083baf964a5201d491fe3',
#     'name': 'Army and Navy Club',
#     'location': {'address': '901 17th St NW',
#      'crossStreet': 'I St NW',
#      'lat': 38.901523,
#      'lng': -77.038166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.901523,
#        'lng': -77.038166}],
#      'distance': 447,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['901 17th St NW (I St NW)',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4c06fc128b4520a15b518697',
#     'name': 'Eden',
#     'location': {'address': '1716 I St NW',
#      'crossStreet': 'btwn 17th & 18th St NW',
#      'lat': 38.90132561536772,
#      'lng': -77.0402633075014,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90132561536772,
#        'lng': -77.0402633075014}],
#      'distance': 515,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1716 I St NW (btwn 17th & 18th St NW)',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '32687984'},
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4b61c46bf964a52072212ae3',
#     'name': 'Metropolitan Club',
#     'location': {'address': '1700 H St NW',
#      'crossStreet': 'at 17th St. NW',
#      'lat': 38.900261466493134,
#      'lng': -77.03984732941163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.900261466493134,
#        'lng': -77.03984732941163}],
#      'distance': 403,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1700 H St NW (at 17th St. NW)',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4deefb944765f83613cdba6e',
#       'name': 'Historic Site',
#       'pluralName': 'Historic Sites',
#       'shortName': 'Historic Site',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4e85dc0bb8f7d7031ea2f5dd',
#     'name': 'Cosmos Club Historic Site',
#     'location': {'lat': 38.90029936995895,
#      'lng': -77.03561913048917,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90029936995895,
#        'lng': -77.03561913048917}],
#      'distance': 300,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '574dff2f498ebb5c6ea8ee15',
#     'name': 'Club V Fitness Center',
#     'location': {'address': '1750 Pennsylvania Ave NW',
#      'lat': 38.89911,
#      'lng': -77.040644,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89911,
#        'lng': -77.040644}],
#      'distance': 387,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1750 Pennsylvania Ave NW',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '50f1af25e4b04eb63df0a5bc',
#     'name': 'Club 531',
#     'location': {'lat': 38.90047,
#      'lng': -77.033812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90047,
#        'lng': -77.033812}],
#      'distance': 389,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C. 20005', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '58b456460bc55b2c38e5c782',
#     'name': 'Washington Press Club Foundation',
#     'location': {'lat': 38.896963,
#      'lng': -77.031319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.896963,
#        'lng': -77.031319}],
#      'distance': 460,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '5cef1215588e36002c139b48',
#     'name': 'Club Quarters Hotel Washington DC',
#     'location': {'address': '839 17th St NW Washington DC',
#      'lat': 38.901398,
#      'lng': -77.038839,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.901398,
#        'lng': -77.038839}],
#      'distance': 456,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['839 17th St NW Washington DC',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '53415e29498e416445ab9a43',
#     'name': 'University Club Terrace',
#     'location': {'lat': 38.901726,
#      'lng': -77.034483,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.901726,
#        'lng': -77.034483}],
#      'distance': 482,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a35',
#       'name': 'Club House',
#       'pluralName': 'Club Houses',
#       'shortName': 'Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4c4081186c1a9521bb4ab96a',
#     'name': 'National Press Club Library',
#     'location': {'address': '529 14th St NW Fl 13',
#      'lat': 38.8970014246388,
#      'lng': -77.03154196433786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8970014246388,
#        'lng': -77.03154196433786}],
#      'distance': 441,
#      'postalCode': '20045',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW Fl 13',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '53e80b7f498ef2e63f533509',
#     'name': 'Club Quarters',
#     'location': {'address': '839 17th St NW',
#      'lat': 38.90231557115177,
#      'lng': -77.0390320183038,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90231557115177,
#        'lng': -77.0390320183038}],
#      'distance': 556,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['839 17th St NW',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '52835cd1498e1020cead73de',
#     'name': 'Club Quarters Fitness Center',
#     'location': {'lat': 38.90103825701401,
#      'lng': -77.03945370286118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90103825701401,
#        'lng': -77.03945370286118}],
#      'distance': 448,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '502f77c7e4b0c17c82278af0',
#     'name': 'capital city hiking club',
#     'location': {'lat': 38.90202936205062,
#      'lng': -77.03658059627693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90202936205062,
#        'lng': -77.03658059627693}],
#      'distance': 481,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C. 20006', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d159941735',
#       'name': 'Trail',
#       'pluralName': 'Trails',
#       'shortName': 'Trail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '568c4e4c498eb9cda6525131',
#     'name': 'National Press Club Gym',
#     'location': {'lat': 38.897198,
#      'lng': -77.031294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.897198,
#        'lng': -77.031294}],
#      'distance': 459,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4c2c96738ef52d7f191933ba',
#     'name': 'International Club Building',
#     'location': {'address': '1800 K Street',
#      'lat': 38.90169,
#      'lng': -77.04156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90169,
#        'lng': -77.04156}],
#      'distance': 620,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'District of Columbia',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1800 K Street',
#       'District of Columbia, D.C. 20006',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4b22768af964a5202b4724e3',
#     'name': 'The Reliable Source',
#     'location': {'address': '529 14th St NW',
#      'lat': 38.897006246281926,
#      'lng': -77.03190650246175,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.897006246281926,
#        'lng': -77.03190650246175}],
#      'distance': 409,
#      'postalCode': '20045',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61079459'},
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '5019b1cde4b0ea253e810b72',
#     'name': 'JW Marriott Gym',
#     'location': {'address': '1331 Pennsylvania Ave NW',
#      'lat': 38.89644758158134,
#      'lng': -77.03124324005303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89644758158134,
#        'lng': -77.03124324005303}],
#      'distance': 480,
#      'postalCode': '20004',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1331 Pennsylvania Ave NW',
#       'Washington, D.C. 20004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '131925826'},
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4c1fa5d7fcf8c9b6ccf8ae0b',
#     'name': 'The Edward R. Murrow Room',
#     'location': {'address': '529 14th St NW',
#      'lat': 38.8970089319705,
#      'lng': -77.03132336541329,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8970089319705,
#        'lng': -77.03132336541329}],
#      'distance': 459,
#      'postalCode': '20045',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12d941735',
#       'name': 'Monument / Landmark',
#       'pluralName': 'Monuments / Landmarks',
#       'shortName': 'Landmark',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4ba24ebaf964a520c6eb37e3',
#     'name': 'The Fourth Estate',
#     'location': {'address': '529 14th St NW',
#      'lat': 38.89704651525907,
#      'lng': -77.03125698111505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89704651525907,
#        'lng': -77.03125698111505}],
#      'distance': 464,
#      'postalCode': '20045',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61079458'},
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '502f9250e4b0bf3e6a1313bf',
#     'name': 'Community Club',
#     'location': {'address': '1313 New York Ave NW',
#      'lat': 38.90009754080006,
#      'lng': -77.03125890853156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90009754080006,
#        'lng': -77.03125890853156}],
#      'distance': 530,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1313 New York Ave NW',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4bfeaf55261eb713cc374ad7',
#     'name': 'Truman Lounge',
#     'location': {'address': '529 14th St NW',
#      'lat': 38.89713144962554,
#      'lng': -77.03167385454267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89713144962554,
#        'lng': -77.03167385454267}],
#      'distance': 427,
#      'postalCode': '20045',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False},
#    {'id': '4b43a883f964a52077e525e3',
#     'name': 'Cuts By Hugo',
#     'location': {'address': '529 14th St NW Ste 204',
#      'lat': 38.89716593012571,
#      'lng': -77.03135866423384,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89716593012571,
#        'lng': -77.03135866423384}],
#      'distance': 453,
#      'postalCode': '20045',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW Ste 204',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580532974',
#     'hasPerk': False}]}}

# %%
# Get relevant parts of the JSON

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                  name  \
# 0  4b5dce76f964a520b96c29e3  Club Quarters Hotel in Washington DC
# 1  4a8c8166f964a520470e20e3                       The Bombay Club
# 2  4ab16c5df964a5206b6920e3               The National Press Club
# 3  46a083baf964a5201d491fe3                    Army and Navy Club
# 4  4c06fc128b4520a15b518697                                  Eden
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1580532974    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1580532974    False
# 2  [{'id': '4bf58dd8d48988d171941735', 'name': 'E...  v-1580532974    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1580532974    False
# 4  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1580532974    False
#
#          location.address  location.lat  location.lng  \
# 0      839 17th Street NW     38.901081    -77.039172
# 1  815 Connecticut Ave NW     38.900822    -77.038246
# 2          529 14th St NW     38.897101    -77.031305
# 3          901 17th St NW     38.901523    -77.038166
# 4            1716 I St NW     38.901326    -77.040263
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 38.901081, 'lng':...                439
# 1  [{'label': 'display', 'lat': 38.90082247535677...                377
# 2  [{'label': 'display', 'lat': 38.89710084420871...                459
# 3  [{'label': 'display', 'lat': 38.901523, 'lng':...                447
# 4  [{'label': 'display', 'lat': 38.90132561536772...                515
#
#   location.postalCode location.cc location.city location.state  \
# 0               20006          US    Washington           D.C.
# 1               20006          US    Washington           D.C.
# 2               20045          US    Washington           D.C.
# 3               20006          US    Washington           D.C.
# 4               20006          US    Washington           D.C.
#
#   location.country                          location.formattedAddress  \
# 0    United States  [839 17th Street NW, Washington, D.C. 20006, U...
# 1    United States  [815 Connecticut Ave NW, Washington, D.C. 2000...
# 2    United States  [529 14th St NW (F St. NW), Washington, D.C. 2...
# 3    United States  [901 17th St NW (I St NW), Washington, D.C. 20...
# 4    United States  [1716 I St NW (btwn 17th & 18th St NW), Washin...
#
#      location.crossStreet            location.neighborhood venuePage.id
# 0                     NaN                              NaN          NaN
# 1                     NaN                              NaN          NaN
# 2                F St. NW  Downtown-Penn Quarter-Chinatown     66869294
# 3                 I St NW                              NaN          NaN
# 4  btwn 17th & 18th St NW                              NaN     32687984

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                     name               categories  \
# 0   Club Quarters Hotel in Washington DC                    Hotel
# 1                        The Bombay Club        Indian Restaurant
# 2                The National Press Club              Event Space
# 3                     Army and Navy Club                    Hotel
# 4                                   Eden                Nightclub
# 5                      Metropolitan Club            Historic Site
# 6              Cosmos Club Historic Site     Other Great Outdoors
# 7                  Club V Fitness Center                      Gym
# 8                               Club 531       Salon / Barbershop
# 9       Washington Press Club Foundation                   Office
# 10     Club Quarters Hotel Washington DC                    Hotel
# 11               University Club Terrace               Club House
# 12           National Press Club Library                  Library
# 13                         Club Quarters                 Building
# 14          Club Quarters Fitness Center                      Gym
# 15              capital city hiking club                    Trail
# 16               National Press Club Gym                      Gym
# 17           International Club Building                     None
# 18                   The Reliable Source                      Bar
# 19                       JW Marriott Gym                      Gym
# 20             The Edward R. Murrow Room      Monument / Landmark
# 21                     The Fourth Estate  New American Restaurant
# 22                        Community Club           Student Center
# 23                         Truman Lounge                   Lounge
# 24                          Cuts By Hugo       Salon / Barbershop
#
#                          address        lat        lng  \
# 0             839 17th Street NW  38.901081 -77.039172
# 1         815 Connecticut Ave NW  38.900822 -77.038246
# 2                 529 14th St NW  38.897101 -77.031305
# 3                 901 17th St NW  38.901523 -77.038166
# 4                   1716 I St NW  38.901326 -77.040263
# 5                   1700 H St NW  38.900261 -77.039847
# 6                            NaN  38.900299 -77.035619
# 7       1750 Pennsylvania Ave NW  38.899110 -77.040644
# 8                            NaN  38.900470 -77.033812
# 9                            NaN  38.896963 -77.031319
# 10  839 17th St NW Washington DC  38.901398 -77.038839
# 11                           NaN  38.901726 -77.034483
# 12          529 14th St NW Fl 13  38.897001 -77.031542
# 13                839 17th St NW  38.902316 -77.039032
# 14                           NaN  38.901038 -77.039454
# 15                           NaN  38.902029 -77.036581
# 16                           NaN  38.897198 -77.031294
# 17                 1800 K Street  38.901690 -77.041560
# 18                529 14th St NW  38.897006 -77.031907
# 19      1331 Pennsylvania Ave NW  38.896448 -77.031243
# 20                529 14th St NW  38.897009 -77.031323
# 21                529 14th St NW  38.897047 -77.031257
# 22          1313 New York Ave NW  38.900098 -77.031259
# 23                529 14th St NW  38.897131 -77.031674
# 24        529 14th St NW Ste 204  38.897166 -77.031359
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 38.901081, 'lng':...       439      20006
# 1   [{'label': 'display', 'lat': 38.90082247535677...       377      20006
# 2   [{'label': 'display', 'lat': 38.89710084420871...       459      20045
# 3   [{'label': 'display', 'lat': 38.901523, 'lng':...       447      20006
# 4   [{'label': 'display', 'lat': 38.90132561536772...       515      20006
# 5   [{'label': 'display', 'lat': 38.90026146649313...       403      20006
# 6   [{'label': 'display', 'lat': 38.90029936995895...       300        NaN
# 7   [{'label': 'display', 'lat': 38.89911, 'lng': ...       387      20006
# 8   [{'label': 'display', 'lat': 38.90047, 'lng': ...       389      20005
# 9   [{'label': 'display', 'lat': 38.896963, 'lng':...       460        NaN
# 10  [{'label': 'display', 'lat': 38.901398, 'lng':...       456      20006
# 11  [{'label': 'display', 'lat': 38.901726, 'lng':...       482        NaN
# 12  [{'label': 'display', 'lat': 38.8970014246388,...       441      20045
# 13  [{'label': 'display', 'lat': 38.90231557115177...       556      20006
# 14  [{'label': 'display', 'lat': 38.90103825701401...       448        NaN
# 15  [{'label': 'display', 'lat': 38.90202936205062...       481      20006
# 16  [{'label': 'display', 'lat': 38.897198, 'lng':...       459        NaN
# 17  [{'label': 'display', 'lat': 38.90169, 'lng': ...       620      20006
# 18  [{'label': 'display', 'lat': 38.89700624628192...       409      20045
# 19  [{'label': 'display', 'lat': 38.89644758158134...       480      20004
# 20  [{'label': 'display', 'lat': 38.8970089319705,...       459      20045
# 21  [{'label': 'display', 'lat': 38.89704651525907...       464      20045
# 22  [{'label': 'display', 'lat': 38.90009754080006...       530      20005
# 23  [{'label': 'display', 'lat': 38.89713144962554...       427      20045
# 24  [{'label': 'display', 'lat': 38.89716593012571...       453      20045
#
#     cc                  city state        country  \
# 0   US            Washington  D.C.  United States
# 1   US            Washington  D.C.  United States
# 2   US            Washington  D.C.  United States
# 3   US            Washington  D.C.  United States
# 4   US            Washington  D.C.  United States
# 5   US            Washington  D.C.  United States
# 6   US            Washington  D.C.  United States
# 7   US            Washington  D.C.  United States
# 8   US            Washington  D.C.  United States
# 9   US            Washington  D.C.  United States
# 10  US            Washington  D.C.  United States
# 11  US            Washington  D.C.  United States
# 12  US            Washington  D.C.  United States
# 13  US            Washington  D.C.  United States
# 14  US            Washington  D.C.  United States
# 15  US            Washington  D.C.  United States
# 16  US            Washington  D.C.  United States
# 17  US  District of Columbia  D.C.  United States
# 18  US            Washington  D.C.  United States
# 19  US            Washington  D.C.  United States
# 20  US            Washington  D.C.  United States
# 21  US            Washington  D.C.  United States
# 22  US            Washington  D.C.  United States
# 23  US            Washington  D.C.  United States
# 24  US            Washington  D.C.  United States
#
#                                      formattedAddress             crossStreet  \
# 0   [839 17th Street NW, Washington, D.C. 20006, U...                     NaN
# 1   [815 Connecticut Ave NW, Washington, D.C. 2000...                     NaN
# 2   [529 14th St NW (F St. NW), Washington, D.C. 2...                F St. NW
# 3   [901 17th St NW (I St NW), Washington, D.C. 20...                 I St NW
# 4   [1716 I St NW (btwn 17th & 18th St NW), Washin...  btwn 17th & 18th St NW
# 5   [1700 H St NW (at 17th St. NW), Washington, D....          at 17th St. NW
# 6                   [Washington, D.C., United States]                     NaN
# 7   [1750 Pennsylvania Ave NW, Washington, D.C. 20...                     NaN
# 8             [Washington, D.C. 20005, United States]                     NaN
# 9                   [Washington, D.C., United States]                     NaN
# 10  [839 17th St NW Washington DC, Washington, D.C...                     NaN
# 11                  [Washington, D.C., United States]                     NaN
# 12  [529 14th St NW Fl 13, Washington, D.C. 20045,...                     NaN
# 13  [839 17th St NW, Washington, D.C. 20006, Unite...                     NaN
# 14                  [Washington, D.C., United States]                     NaN
# 15            [Washington, D.C. 20006, United States]                     NaN
# 16                  [Washington, D.C., United States]                     NaN
# 17  [1800 K Street, District of Columbia, D.C. 200...                     NaN
# 18  [529 14th St NW, Washington, D.C. 20045, Unite...                     NaN
# 19  [1331 Pennsylvania Ave NW, Washington, D.C. 20...                     NaN
# 20  [529 14th St NW, Washington, D.C. 20045, Unite...                     NaN
# 21  [529 14th St NW, Washington, D.C. 20045, Unite...                     NaN
# 22  [1313 New York Ave NW, Washington, D.C. 20005,...                     NaN
# 23  [529 14th St NW, Washington, D.C. 20045, Unite...                     NaN
# 24  [529 14th St NW Ste 204, Washington, D.C. 2004...                     NaN
#
#                        neighborhood                        id
# 0                               NaN  4b5dce76f964a520b96c29e3
# 1                               NaN  4a8c8166f964a520470e20e3
# 2   Downtown-Penn Quarter-Chinatown  4ab16c5df964a5206b6920e3
# 3                               NaN  46a083baf964a5201d491fe3
# 4                               NaN  4c06fc128b4520a15b518697
# 5                               NaN  4b61c46bf964a52072212ae3
# 6                               NaN  4e85dc0bb8f7d7031ea2f5dd
# 7                               NaN  574dff2f498ebb5c6ea8ee15
# 8                               NaN  50f1af25e4b04eb63df0a5bc
# 9                               NaN  58b456460bc55b2c38e5c782
# 10                              NaN  5cef1215588e36002c139b48
# 11                              NaN  53415e29498e416445ab9a43
# 12                              NaN  4c4081186c1a9521bb4ab96a
# 13                              NaN  53e80b7f498ef2e63f533509
# 14                              NaN  52835cd1498e1020cead73de
# 15                              NaN  502f77c7e4b0c17c82278af0
# 16                              NaN  568c4e4c498eb9cda6525131
# 17                              NaN  4c2c96738ef52d7f191933ba
# 18                              NaN  4b22768af964a5202b4724e3
# 19                              NaN  5019b1cde4b0ea253e810b72
# 20                              NaN  4c1fa5d7fcf8c9b6ccf8ae0b
# 21                              NaN  4ba24ebaf964a520c6eb37e3
# 22                              NaN  502f9250e4b0bf3e6a1313bf
# 23                              NaN  4bfeaf55261eb713cc374ad7
# 24                              NaN  4b43a883f964a52077e525e3

# %%
# filter 

filtered_categories = set(dataframe_filtered.categories)
filtered_categories
# Out:
# {'Bar',
#  'Building',
#  'Club House',
#  'Event Space',
#  'Gym',
#  'Historic Site',
#  'Hotel',
#  'Indian Restaurant',
#  'Library',
#  'Lounge',
#  'Monument / Landmark',
#  'New American Restaurant',
#  'Nightclub',
#  None,
#  'Office',
#  'Other Great Outdoors',
#  'Salon / Barbershop',
#  'Student Center',
#  'Trail'}
