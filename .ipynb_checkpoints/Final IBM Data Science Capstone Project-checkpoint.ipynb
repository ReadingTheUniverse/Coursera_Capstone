# %% [markdown]
# # Coursera Capstone
#
# ### Introduction and Business Problem
#
# Question:  Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.
#
# Answer:
#
# Two historic and very popular jazz clubs have recently closed in the District of Columbia.  This leaves a underserved market.  In this assignment I seek to determine what neighborhood is the best to open a new jazz club.
#
# ### The Data
#
# Question 2:  Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data.
#
# Answer:  The Foursquare API provides the category of "jazz clubs."  The idea is to cluster the neighborhoods and determine where the hotbeds of jazz are.

# %% [markdown]
# #  Start of Analysis
#
# ## Import necessary libraries for the project

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Data Collection and Wrangling
#
# The data required to complete this analysis is the following:
#
# 	* Neighborhoods of Washington, DC
# 	* Location of current jazz clubs
# 	* Neighborhoods with a strong nightlife
# 	* The ratings of the jazz clubs in the area

# %%
# import the neighborhoods in DC into a dataframe

neighborhoods = pd.read_csv('Neighborhood_Labels.csv')
neighborhoods.rename(columns={'X': 'location.lng', 'Y': 'location.lat', 'LABEL_NAME':'Neighborhood'}, inplace=True) # rename the columns to match Foursquare convention
neighborhoods = neighborhoods[['location.lng','location.lat','Neighborhood']] # select specific columns in the data
neighborhoods.head()
# Out:
#    location.lng  location.lat           Neighborhood
# 0    -76.980348     38.855658           Fort Stanton
# 1    -76.997950     38.841077       Congress Heights
# 2    -76.995636     38.830237   Washington Highlands
# 3    -77.009271     38.826952               Bellevue
# 4    -76.967660     38.853688  Knox Hill/Buena Vista

# %%
# Provide criteria for the Foursquare API

CLIENT_ID = 'OCWMDYHM2G1414ACMQSU1M4JUE2RGENSCHFRUDUYSIAKH4EC' # your Foursquare ID
CLIENT_SECRET = 'T3ZHW0FVTOXETI3WBQN1WJVWZ4IS1K02KKCUOPVEW5EJTQ0Z' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 400
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: OCWMDYHM2G1414ACMQSU1M4JUE2RGENSCHFRUDUYSIAKH4EC
# CLIENT_SECRET:T3ZHW0FVTOXETI3WBQN1WJVWZ4IS1K02KKCUOPVEW5EJTQ0Z

# %%
# Locate address in Washington, DC to get a lat long

address = 'Adams Morgan, DC'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 38.9215002 -77.0421992

# %%
# Search for a specific category

search_query = 'jazz'
radius = 4000
print(search_query + ' .... OK!')
# Out:
# jazz .... OK!

# %%
# Add search query to url 

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=OCWMDYHM2G1414ACMQSU1M4JUE2RGENSCHFRUDUYSIAKH4EC&client_secret=T3ZHW0FVTOXETI3WBQN1WJVWZ4IS1K02KKCUOPVEW5EJTQ0Z&ll=38.9215002,-77.0421992&v=20180604&query=jazz&radius=4000&limit=400'

# %%
# get the json from Foursquare

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e365236923935001cdb40be'},
#  'response': {'venues': [{'id': '4ad66635f964a520040721e3',
#     'name': 'Twins Jazz',
#     'location': {'address': '1344 U St NW',
#      'crossStreet': 'btwn 13th & 14th St NW',
#      'lat': 38.91688730237296,
#      'lng': -77.03138484898851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.91688730237296,
#        'lng': -77.03138484898851}],
#      'distance': 1068,
#      'postalCode': '20009',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1344 U St NW (btwn 13th & 14th St NW)',
#       'Washington, D.C. 20009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '288013',
#      'url': 'https://www.grubhub.com/restaurant/twins-jazz-1344-u-st-nw-washington/288013?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=288013',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '50f097a9e4b0b237b6448e09',
#     'name': 'DC Jazz Festival Production Office',
#     'location': {'address': 'Mozart Pl',
#      'lat': 38.924954322910025,
#      'lng': -77.03782318108591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.924954322910025,
#        'lng': -77.03782318108591}],
#      'distance': 539,
#      'postalCode': '20009',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Mozart Pl',
#       'Washington, D.C. 20009',
#       'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '4c1580c5a1010f4795354e18',
#     'name': 'Center For Preservation Of Jazz And Blues',
#     'location': {'lat': 38.91157,
#      'lng': -77.03210933333334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.91157,
#        'lng': -77.03210933333334}],
#      'distance': 1409,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '4dc74448fa76d685ce0ec090',
#     'name': 'DC Jazz Loft',
#     'location': {'address': '1402 Meridian Pl NW',
#      'lat': 38.933366,
#      'lng': -77.033001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.933366,
#        'lng': -77.033001}],
#      'distance': 1542,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1402 Meridian Pl NW',
#       'Washington, D.C.',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '56bcb3cc498e583f3373a1b9',
#     'name': 'The Jazz Flat',
#     'location': {'lat': 38.91632,
#      'lng': -77.013747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.91632,
#        'lng': -77.013747}],
#      'distance': 2530,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '55e9faeb498ee151a596c94f',
#     'name': 'LeRoy Neiman Jazz Cafe',
#     'location': {'address': '14th St and Constitution Ave, NW',
#      'crossStreet': 'National Museum of American History',
#      'lat': 38.89198937986075,
#      'lng': -77.03012202978927,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89198937986075,
#        'lng': -77.03012202978927}],
#      'distance': 3447,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['14th St and Constitution Ave, NW (National Museum of American History)',
#       'Washington, D.C.',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '4cd06c2ede0f6dcb50a76a63',
#     'name': 'Kennedy Center Jazz Club',
#     'location': {'address': '2700 F St NW',
#      'lat': 38.895804999999996,
#      'lng': -77.055673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.895804999999996,
#        'lng': -77.055673}],
#      'distance': 3089,
#      'postalCode': '20566',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2700 F St NW',
#       'Washington, D.C. 20566',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '50bc3af2e4b05be7dcfbbd30',
#     'name': 'The Salted Peanut Jazz Lounge',
#     'location': {'lat': 38.89782973195035,
#      'lng': -77.04808385684144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89782973195035,
#        'lng': -77.04808385684144}],
#      'distance': 2683,
#      'postalCode': '20037',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C. 20037', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '58853ae0375c4a342e3d206a',
#     'name': "Alice's Jazz and Cultural Society",
#     'location': {'address': '2813 12th St NE',
#      'crossStreet': 'at Franklin St NE',
#      'lat': 38.925583,
#      'lng': -76.990305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.925583,
#        'lng': -76.990305}],
#      'distance': 4517,
#      'postalCode': '20017',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2813 12th St NE (at Franklin St NE)',
#       'Washington, D.C. 20017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '4d5bf3e9f57ca09056f97be0',
#     'name': 'Felix E. Grant Jazz Archives',
#     'location': {'address': '4200 Connecticut Ave NW',
#      'crossStreet': 'Connecticut Ave. & Van Ness St.',
#      'lat': 38.94362273517887,
#      'lng': -77.06392049789429,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.94362273517887,
#        'lng': -77.06392049789429}],
#      'distance': 3098,
#      'postalCode': '20008',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['4200 Connecticut Ave NW (Connecticut Ave. & Van Ness St.)',
#       'Washington, D.C. 20008',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '566b752c498e86bfa811289f',
#     'name': 'Jazz & Cultural Society (JACS)',
#     'location': {'address': '2813 12th St NE',
#      'lat': 38.925847,
#      'lng': -76.990206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.925847,
#        'lng': -76.990206}],
#      'distance': 4528,
#      'postalCode': '20017',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2813 12th St NE',
#       'Washington, D.C. 20017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '532d0e7c498e3c6c34086182',
#     'name': 'Jazzercise',
#     'location': {'address': '2303 14th St NW',
#      'lat': 38.920665,
#      'lng': -77.031515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.920665,
#        'lng': -77.031515}],
#      'distance': 929,
#      'postalCode': '20009',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2303 14th St NW',
#       'Washington, D.C. 20009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '59144a316e46503e5f93e41b',
#     'name': "Castello's Fine Dining Restaurant and Live Jazz",
#     'location': {'address': '5201 Georgia Ave Nw',
#      'lat': 38.9530532,
#      'lng': -77.0272255,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.9530532,
#        'lng': -77.0272255}],
#      'distance': 3744,
#      'postalCode': '20011',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['5201 Georgia Ave Nw',
#       'Washington, WA 20011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '425210266'},
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '572c4b16498e31a38f321ccf',
#     'name': 'Sculpture Garden Pavilion Café Jazz In The Garden Series',
#     'location': {'lat': 38.8896766,
#      'lng': -77.0197426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8896766,
#        'lng': -77.0197426}],
#      'distance': 4041,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1724344',
#      'url': 'https://www.grubhub.com/restaurant/sculpture-garden-pavillion-cafe-401-constitution-avenue-northwest-washington/1724344?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1724344',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1580618369',
#     'hasPerk': False},
#    {'id': '4f030cb6e300fdc04be22a9a',
#     'name': "Howard University - Jazzman's Cafe",
#     'location': {'address': '2400 6th St NW',
#      'lat': 38.922976,
#      'lng': -77.021841,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.922976,
#        'lng': -77.021841}],
#      'distance': 1770,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2400 6th St NW',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580618369',
#     'hasPerk': False}]}}

# %%
# Get relevant parts of the JSON

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                       name  \
# 0  4ad66635f964a520040721e3                                 Twins Jazz
# 1  50f097a9e4b0b237b6448e09         DC Jazz Festival Production Office
# 2  4c1580c5a1010f4795354e18  Center For Preservation Of Jazz And Blues
# 3  4dc74448fa76d685ce0ec090                               DC Jazz Loft
# 4  56bcb3cc498e583f3373a1b9                              The Jazz Flat
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...  v-1580618369    False
# 1  [{'id': '50328a8e91d4c4b30a586d6c', 'name': 'N...  v-1580618369    False
# 2  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...  v-1580618369    False
# 3  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...  v-1580618369    False
# 4  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1580618369    False
#
#       location.address    location.crossStreet  location.lat  location.lng  \
# 0         1344 U St NW  btwn 13th & 14th St NW     38.916887    -77.031385
# 1            Mozart Pl                     NaN     38.924954    -77.037823
# 2                  NaN                     NaN     38.911570    -77.032109
# 3  1402 Meridian Pl NW                     NaN     38.933366    -77.033001
# 4                  NaN                     NaN     38.916320    -77.013747
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 38.91688730237296...               1068
# 1  [{'label': 'display', 'lat': 38.92495432291002...                539
# 2  [{'label': 'display', 'lat': 38.91157, 'lng': ...               1409
# 3  [{'label': 'display', 'lat': 38.933366, 'lng':...               1542
# 4  [{'label': 'display', 'lat': 38.91632, 'lng': ...               2530
#
#   location.postalCode location.cc location.city location.state  \
# 0               20009          US    Washington           D.C.
# 1               20009          US    Washington           D.C.
# 2                 NaN          US    Washington           D.C.
# 3                 NaN          US    Washington           D.C.
# 4                 NaN          US    Washington           D.C.
#
#   location.country                          location.formattedAddress  \
# 0    United States  [1344 U St NW (btwn 13th & 14th St NW), Washin...
# 1    United States  [Mozart Pl, Washington, D.C. 20009, United Sta...
# 2    United States                  [Washington, D.C., United States]
# 3    United States  [1402 Meridian Pl NW, Washington, D.C., United...
# 4    United States                  [Washington, D.C., United States]
#
#   delivery.id                                       delivery.url  \
# 0      288013  https://www.grubhub.com/restaurant/twins-jazz-...
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0                grubhub  https://fastly.4sqi.net/img/general/cap/
# 1                    NaN                                       NaN
# 2                    NaN                                       NaN
# 3                    NaN                                       NaN
# 4                    NaN                                       NaN
#
#   delivery.provider.icon.sizes              delivery.provider.icon.name  \
# 0                     [40, 50]  /delivery_provider_grubhub_20180129.png
# 1                          NaN                                      NaN
# 2                          NaN                                      NaN
# 3                          NaN                                      NaN
# 4                          NaN                                      NaN
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                          Twins Jazz
# 1                  DC Jazz Festival Production Office
# 2           Center For Preservation Of Jazz And Blues
# 3                                        DC Jazz Loft
# 4                                       The Jazz Flat
# 5                              LeRoy Neiman Jazz Cafe
# 6                            Kennedy Center Jazz Club
# 7                       The Salted Peanut Jazz Lounge
# 8                   Alice's Jazz and Cultural Society
# 9                        Felix E. Grant Jazz Archives
# 10                     Jazz & Cultural Society (JACS)
# 11                                         Jazzercise
# 12    Castello's Fine Dining Restaurant and Live Jazz
# 13  Sculpture Garden Pavilion Café Jazz In The Gar...
# 14                 Howard University - Jazzman's Cafe
#
#                                   categories  \
# 0                                  Jazz Club
# 1                                 Non-Profit
# 2                                  Jazz Club
# 3                                  Jazz Club
# 4   Residential Building (Apartment / Condo)
# 5                                       Café
# 6                                  Jazz Club
# 7                                     Lounge
# 8                                  Jazz Club
# 9                      General Entertainment
# 10                               Music Venue
# 11                        Miscellaneous Shop
# 12                   New American Restaurant
# 13                               Music Venue
# 14                                      Café
#
#                              address                          crossStreet  \
# 0                       1344 U St NW               btwn 13th & 14th St NW
# 1                          Mozart Pl                                  NaN
# 2                                NaN                                  NaN
# 3                1402 Meridian Pl NW                                  NaN
# 4                                NaN                                  NaN
# 5   14th St and Constitution Ave, NW  National Museum of American History
# 6                       2700 F St NW                                  NaN
# 7                                NaN                                  NaN
# 8                    2813 12th St NE                    at Franklin St NE
# 9            4200 Connecticut Ave NW      Connecticut Ave. & Van Ness St.
# 10                   2813 12th St NE                                  NaN
# 11                   2303 14th St NW                                  NaN
# 12               5201 Georgia Ave Nw                                  NaN
# 13                               NaN                                  NaN
# 14                    2400 6th St NW                                  NaN
#
#           lat        lng                                     labeledLatLngs  \
# 0   38.916887 -77.031385  [{'label': 'display', 'lat': 38.91688730237296...
# 1   38.924954 -77.037823  [{'label': 'display', 'lat': 38.92495432291002...
# 2   38.911570 -77.032109  [{'label': 'display', 'lat': 38.91157, 'lng': ...
# 3   38.933366 -77.033001  [{'label': 'display', 'lat': 38.933366, 'lng':...
# 4   38.916320 -77.013747  [{'label': 'display', 'lat': 38.91632, 'lng': ...
# 5   38.891989 -77.030122  [{'label': 'display', 'lat': 38.89198937986075...
# 6   38.895805 -77.055673  [{'label': 'display', 'lat': 38.89580499999999...
# 7   38.897830 -77.048084  [{'label': 'display', 'lat': 38.89782973195035...
# 8   38.925583 -76.990305  [{'label': 'display', 'lat': 38.925583, 'lng':...
# 9   38.943623 -77.063920  [{'label': 'display', 'lat': 38.94362273517887...
# 10  38.925847 -76.990206  [{'label': 'display', 'lat': 38.925847, 'lng':...
# 11  38.920665 -77.031515  [{'label': 'display', 'lat': 38.920665, 'lng':...
# 12  38.953053 -77.027226  [{'label': 'display', 'lat': 38.9530532, 'lng'...
# 13  38.889677 -77.019743  [{'label': 'display', 'lat': 38.8896766, 'lng'...
# 14  38.922976 -77.021841  [{'label': 'display', 'lat': 38.922976, 'lng':...
#
#     distance postalCode  cc        city state        country  \
# 0       1068      20009  US  Washington  D.C.  United States
# 1        539      20009  US  Washington  D.C.  United States
# 2       1409        NaN  US  Washington  D.C.  United States
# 3       1542        NaN  US  Washington  D.C.  United States
# 4       2530        NaN  US  Washington  D.C.  United States
# 5       3447        NaN  US  Washington  D.C.  United States
# 6       3089      20566  US  Washington  D.C.  United States
# 7       2683      20037  US  Washington  D.C.  United States
# 8       4517      20017  US  Washington  D.C.  United States
# 9       3098      20008  US  Washington  D.C.  United States
# 10      4528      20017  US  Washington  D.C.  United States
# 11       929      20009  US  Washington  D.C.  United States
# 12      3744      20011  US  Washington    WA  United States
# 13      4041        NaN  US  Washington  D.C.  United States
# 14      1770      20001  US  Washington  D.C.  United States
#
#                                      formattedAddress  \
# 0   [1344 U St NW (btwn 13th & 14th St NW), Washin...
# 1   [Mozart Pl, Washington, D.C. 20009, United Sta...
# 2                   [Washington, D.C., United States]
# 3   [1402 Meridian Pl NW, Washington, D.C., United...
# 4                   [Washington, D.C., United States]
# 5   [14th St and Constitution Ave, NW (National Mu...
# 6   [2700 F St NW, Washington, D.C. 20566, United ...
# 7             [Washington, D.C. 20037, United States]
# 8   [2813 12th St NE (at Franklin St NE), Washingt...
# 9   [4200 Connecticut Ave NW (Connecticut Ave. & V...
# 10  [2813 12th St NE, Washington, D.C. 20017, Unit...
# 11  [2303 14th St NW, Washington, D.C. 20009, Unit...
# 12  [5201 Georgia Ave Nw, Washington, WA 20011, Un...
# 13                  [Washington, D.C., United States]
# 14  [2400 6th St NW, Washington, D.C. 20001, Unite...
#
#                           id
# 0   4ad66635f964a520040721e3
# 1   50f097a9e4b0b237b6448e09
# 2   4c1580c5a1010f4795354e18
# 3   4dc74448fa76d685ce0ec090
# 4   56bcb3cc498e583f3373a1b9
# 5   55e9faeb498ee151a596c94f
# 6   4cd06c2ede0f6dcb50a76a63
# 7   50bc3af2e4b05be7dcfbbd30
# 8   58853ae0375c4a342e3d206a
# 9   4d5bf3e9f57ca09056f97be0
# 10  566b752c498e86bfa811289f
# 11  532d0e7c498e3c6c34086182
# 12  59144a316e46503e5f93e41b
# 13  572c4b16498e31a38f321ccf
# 14  4f030cb6e300fdc04be22a9a

# %%
# filter 

filtered_categories = set(dataframe_filtered.categories)
filtered_categories
# Out:
# {'Café',
#  'General Entertainment',
#  'Jazz Club',
#  'Lounge',
#  'Miscellaneous Shop',
#  'Music Venue',
#  'New American Restaurant',
#  'Non-Profit',
#  'Residential Building (Apartment / Condo)'}

# %%
dataframe_filtered.describe()
# Out:
#              lat        lng     distance
# count  15.000000  15.000000    15.000000
# mean   38.918010 -77.028447  2595.600000
# std     0.018409   0.020323  1325.762681
# min    38.889677 -77.063920   539.000000
# 25%    38.904700 -77.035412  1475.500000
# 50%    38.920665 -77.031385  2683.000000
# 75%    38.925715 -77.020792  3595.500000
# max    38.953053 -76.990206  4528.000000
